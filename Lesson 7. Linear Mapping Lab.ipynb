# %% [markdown]
# ![%EC%BA%A1%EC%B2%98_2019_06_26_23_59_39_806.png](attachment:%EC%BA%A1%EC%B2%98_2019_06_26_23_59_39_806.png)

# %% [markdown]
# ![Part%204.png](attachment:Part%204.png)

# %% [markdown]
# ![%EC%BA%A1%EC%B2%98_2019_06_27_00_47_49_771.png](attachment:%EC%BA%A1%EC%B2%98_2019_06_27_00_47_49_771.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.youtube.com/watch?v=lmF-V8emukA

# %% [markdown]
# <video controls src="etc/G-1 - AIPND Linear Algebra_ Plotting a Transformed Vector v3.mp4" />

# %% [markdown]
# https://www.youtube.com/watch?v=TavNlmrIuwI

# %% [markdown]
# <video controls src="etc/G-2 - AIPND Linear Algebra_ Matrix Multiplication v2.mp4" />

# %% [markdown]
# https://www.youtube.com/watch?v=wmHk5cL5NJA

# %% [markdown]
# <video controls src="etc/G-3 - AIPND Linear Algebra_ Currency Conversion Problem v2.mp4" />
